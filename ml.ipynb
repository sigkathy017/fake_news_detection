# %%
from pycaret.classification import *

# %%
import pandas as pd

real_news = pd.read_csv('real_data.csv')
fake_news = pd.read_csv('fake_data.csv')

# %% [markdown]
# Preprocessing

# %%
real_news['label'] = 0
fake_news['label'] = 1

# %%
news = pd.concat([real_news, fake_news], ignore_index=True)

# %%
news.shape
# Out:
# (44898, 778)

# %%
news.head()
# Out:
#    NOUN  VERB  ADJ  ADV  PRON  PER  ORG  LOC  token_count     emb_0  ...  \
# 0   167   104   61   27    38    9   42   15          882 -0.344786  ...
# 1   151   103   38   14    25   12   26   11          711 -0.472813  ...
# 2    89    60   29    6    38   16   24   18          519 -0.352055  ...
# 3    74    47   26   11    18   16   16   30          432 -0.482031  ...
# 4   227    83   67   33    40   11   64   23          990 -0.395008  ...
#
#     emb_759   emb_760   emb_761   emb_762   emb_763   emb_764   emb_765  \
# 0  0.962330  1.493958  0.028553 -0.561609  0.039556  0.247863  0.784136
# 1  0.951301  1.549707 -0.046531 -0.323878  0.079172  0.105633  1.009901
# 2  0.897749  1.369763  0.117088 -0.410743  0.112445  0.203302  1.009904
# 3  1.108111  1.561908 -0.089562 -0.531489  0.287689  0.186430  0.743534
# 4  0.979328  1.472806  0.005544 -0.485526  0.037237  0.079488  0.954526
#
#     emb_766   emb_767  label
# 0  1.055186 -0.011686      0
# 1  1.334306  0.098103      0
# 2  1.014667  0.049866      0
# 3  1.143231  0.109753      0
# 4  1.236557  0.041941      0
#
# [5 rows x 778 columns]

# %%
news.dropna(inplace=True)

# %%
duplicates = news[news.duplicated(keep=False)]

# %%
duplicates['label'].value_counts()
# Out:
# label
# 1    5166
# 0     237
# Name: count, dtype: int64

# %%
data = news.drop_duplicates(keep=False)

# %%
data.shape
# Out:
# (39495, 778)

# %% [markdown]
# Balance Dataset

# %%
from sklearn.utils import resample

# %%
target0 = data[data['label']==0]
target1 = data[data['label']==1]

# %%
print(target0.shape, target1.shape)
# Out:
# (21180, 778) (18315, 778)

# %%
target0 = resample(target0, replace=True, n_samples=len(target1), random_state=42)

# %%
print(target0.shape, target1.shape)
# Out:
# (18315, 778) (18315, 778)

# %%
balanced_data = pd.concat([target0, target1])
balanced_data['label'].value_counts()
# Out:
# label
# 0    18315
# 1    18315
# Name: count, dtype: int64

# %% [markdown]
# Normalizer

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer

normalizer = Normalizer()

# %%
X = balanced_data.drop('label', axis=1)
y = balanced_data['label']

# %%
print(X.shape, y.shape)
# Out:
# (36630, 777) (36630,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

X_train = pd.DataFrame(X_train, columns=X.columns)
X_test = pd.DataFrame(X_test, columns=X.columns)

# %%
X_train_scaled = normalizer.fit_transform(X_train)
X_test_scaled = normalizer.transform(X_test)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)

# %% [markdown]
# Train Model

# %%
train_data = pd.concat([X_train_scaled, y_train], axis=1)
test_data = pd.concat([X_test_scaled, y_test], axis=1)

# %%
print(train_data.shape, test_data.shape)
# Out:
# (29304, 778) (7326, 778)

# %%
train_data.reset_index(drop=True, inplace=True)
test_data.reset_index(drop=True, inplace=True)

train_data.to_csv('train_data.csv', index=False)
test_data.to_csv('test_data.csv', index=False)

# %%
train_data.head()
# Out:
#        NOUN      VERB       ADJ       ADV      PRON       PER       ORG  \
# 0  0.203840  0.125440  0.031360  0.031360  0.094080  0.000000  0.015680
# 1  0.159370  0.113836  0.056918  0.034151  0.018973  0.045534  0.072096
# 2  0.133885  0.164313  0.033471  0.024343  0.106499  0.027386  0.027386
# 3  0.175322  0.112879  0.033623  0.028820  0.028820  0.045632  0.052837
# 4  0.230981  0.116760  0.027921  0.015230  0.055842  0.005077  0.025383
#
#         LOC  token_count     emb_0  ...   emb_759   emb_760   emb_761  \
# 0  0.015680     0.925118  0.012406  ... -0.017232 -0.017918 -0.003073
# 1  0.037945     0.971401  0.003312  ... -0.006045 -0.005730 -0.000492
# 2  0.039557     0.967622 -0.002166  ...  0.002536  0.004577 -0.001113
# 3  0.031222     0.972679 -0.000748  ...  0.002520  0.003927 -0.000256
# 4  0.027921     0.961999 -0.001562  ...  0.002528  0.003674 -0.000211
#
#     emb_762   emb_763   emb_764   emb_765   emb_766   emb_767  label
# 0  0.001308  0.001871 -0.009364 -0.004818 -0.011782 -0.003567      1
# 1  0.000540 -0.000797 -0.002718 -0.004061 -0.003820  0.000320      1
# 2 -0.002376  0.003084 -0.001353  0.001788  0.004076 -0.000330      1
# 3 -0.001537  0.000592 -0.000080  0.001324  0.002279  0.000457      0
# 4 -0.001029  0.000718  0.000335  0.002034  0.003893  0.000451      0
#
# [5 rows x 778 columns]

# %%
experiment = ClassificationExperiment()
experiment.setup(
    data=train_data,
    target='label',
    session_id=123,
    preprocess=False,
    normalize=False,
    transformation=False,
    feature_selection=False,
    remove_outliers=False,
    fix_imbalance=False,
    index=False
)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2d058">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d058_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2d058_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d058_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2d058_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2d058_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_2d058_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2d058_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2d058_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_2d058_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2d058_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_2d058_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_2d058_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2d058_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_2d058_row3_col1" class="data row3 col1" >(29304, 778)</td>
#     </tr>
#     <tr>
#       <th id="T_2d058_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2d058_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_2d058_row4_col1" class="data row4 col1" >(29304, 778)</td>
#     </tr>
#     <tr>
#       <th id="T_2d058_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2d058_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_2d058_row5_col1" class="data row5 col1" >(20512, 778)</td>
#     </tr>
#     <tr>
#       <th id="T_2d058_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2d058_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_2d058_row6_col1" class="data row6 col1" >(8792, 778)</td>
#     </tr>
#     <tr>
#       <th id="T_2d058_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2d058_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_2d058_row7_col1" class="data row7 col1" >777</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = experiment.compare_models()
# Out:
# <style type="text/css">
# #T_cb5b7 th {
#   text-align: left;
# }
# #T_cb5b7_row0_col0, #T_cb5b7_row1_col0, #T_cb5b7_row1_col1, #T_cb5b7_row1_col2, #T_cb5b7_row1_col4, #T_cb5b7_row1_col5, #T_cb5b7_row1_col6, #T_cb5b7_row1_col7, #T_cb5b7_row2_col0, #T_cb5b7_row2_col1, #T_cb5b7_row2_col2, #T_cb5b7_row2_col3, #T_cb5b7_row2_col4, #T_cb5b7_row2_col5, #T_cb5b7_row2_col6, #T_cb5b7_row2_col7, #T_cb5b7_row3_col0, #T_cb5b7_row3_col1, #T_cb5b7_row3_col2, #T_cb5b7_row3_col3, #T_cb5b7_row3_col4, #T_cb5b7_row3_col5, #T_cb5b7_row3_col6, #T_cb5b7_row3_col7, #T_cb5b7_row4_col0, #T_cb5b7_row4_col1, #T_cb5b7_row4_col2, #T_cb5b7_row4_col3, #T_cb5b7_row4_col4, #T_cb5b7_row4_col5, #T_cb5b7_row4_col6, #T_cb5b7_row4_col7, #T_cb5b7_row5_col0, #T_cb5b7_row5_col1, #T_cb5b7_row5_col2, #T_cb5b7_row5_col3, #T_cb5b7_row5_col4, #T_cb5b7_row5_col5, #T_cb5b7_row5_col6, #T_cb5b7_row5_col7, #T_cb5b7_row6_col0, #T_cb5b7_row6_col1, #T_cb5b7_row6_col2, #T_cb5b7_row6_col3, #T_cb5b7_row6_col4, #T_cb5b7_row6_col5, #T_cb5b7_row6_col6, #T_cb5b7_row6_col7, #T_cb5b7_row7_col0, #T_cb5b7_row7_col1, #T_cb5b7_row7_col2, #T_cb5b7_row7_col3, #T_cb5b7_row7_col4, #T_cb5b7_row7_col5, #T_cb5b7_row7_col6, #T_cb5b7_row7_col7, #T_cb5b7_row8_col0, #T_cb5b7_row8_col1, #T_cb5b7_row8_col2, #T_cb5b7_row8_col3, #T_cb5b7_row8_col4, #T_cb5b7_row8_col5, #T_cb5b7_row8_col6, #T_cb5b7_row8_col7, #T_cb5b7_row9_col0, #T_cb5b7_row9_col1, #T_cb5b7_row9_col2, #T_cb5b7_row9_col3, #T_cb5b7_row9_col4, #T_cb5b7_row9_col5, #T_cb5b7_row9_col6, #T_cb5b7_row9_col7, #T_cb5b7_row10_col0, #T_cb5b7_row10_col1, #T_cb5b7_row10_col2, #T_cb5b7_row10_col3, #T_cb5b7_row10_col4, #T_cb5b7_row10_col5, #T_cb5b7_row10_col6, #T_cb5b7_row10_col7, #T_cb5b7_row11_col0, #T_cb5b7_row11_col1, #T_cb5b7_row11_col2, #T_cb5b7_row11_col3, #T_cb5b7_row11_col4, #T_cb5b7_row11_col5, #T_cb5b7_row11_col6, #T_cb5b7_row11_col7, #T_cb5b7_row12_col0, #T_cb5b7_row12_col1, #T_cb5b7_row12_col2, #T_cb5b7_row12_col3, #T_cb5b7_row12_col4, #T_cb5b7_row12_col5, #T_cb5b7_row12_col6, #T_cb5b7_row12_col7, #T_cb5b7_row13_col0, #T_cb5b7_row13_col1, #T_cb5b7_row13_col2, #T_cb5b7_row13_col3, #T_cb5b7_row13_col4, #T_cb5b7_row13_col5, #T_cb5b7_row13_col6, #T_cb5b7_row13_col7 {
#   text-align: left;
# }
# #T_cb5b7_row0_col1, #T_cb5b7_row0_col2, #T_cb5b7_row0_col3, #T_cb5b7_row0_col4, #T_cb5b7_row0_col5, #T_cb5b7_row0_col6, #T_cb5b7_row0_col7, #T_cb5b7_row1_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cb5b7_row0_col8, #T_cb5b7_row1_col8, #T_cb5b7_row2_col8, #T_cb5b7_row3_col8, #T_cb5b7_row4_col8, #T_cb5b7_row5_col8, #T_cb5b7_row6_col8, #T_cb5b7_row7_col8, #T_cb5b7_row8_col8, #T_cb5b7_row9_col8, #T_cb5b7_row10_col8, #T_cb5b7_row11_col8, #T_cb5b7_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cb5b7_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cb5b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb5b7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cb5b7_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_cb5b7_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_cb5b7_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_cb5b7_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_cb5b7_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_cb5b7_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_cb5b7_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_cb5b7_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb5b7_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_cb5b7_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_cb5b7_row0_col1" class="data row0 col1" >0.9972</td>
#       <td id="T_cb5b7_row0_col2" class="data row0 col2" >0.9998</td>
#       <td id="T_cb5b7_row0_col3" class="data row0 col3" >0.9969</td>
#       <td id="T_cb5b7_row0_col4" class="data row0 col4" >0.9975</td>
#       <td id="T_cb5b7_row0_col5" class="data row0 col5" >0.9972</td>
#       <td id="T_cb5b7_row0_col6" class="data row0 col6" >0.9943</td>
#       <td id="T_cb5b7_row0_col7" class="data row0 col7" >0.9943</td>
#       <td id="T_cb5b7_row0_col8" class="data row0 col8" >2.2150</td>
#     </tr>
#     <tr>
#       <th id="T_cb5b7_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_cb5b7_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_cb5b7_row1_col1" class="data row1 col1" >0.9969</td>
#       <td id="T_cb5b7_row1_col2" class="data row1 col2" >0.9996</td>
#       <td id="T_cb5b7_row1_col3" class="data row1 col3" >0.9969</td>
#       <td id="T_cb5b7_row1_col4" class="data row1 col4" >0.9970</td>
#       <td id="T_cb5b7_row1_col5" class="data row1 col5" >0.9969</td>
#       <td id="T_cb5b7_row1_col6" class="data row1 col6" >0.9939</td>
#       <td id="T_cb5b7_row1_col7" class="data row1 col7" >0.9939</td>
#       <td id="T_cb5b7_row1_col8" class="data row1 col8" >44.3860</td>
#     </tr>
#     <tr>
#       <th id="T_cb5b7_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_cb5b7_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_cb5b7_row2_col1" class="data row2 col1" >0.9966</td>
#       <td id="T_cb5b7_row2_col2" class="data row2 col2" >0.9995</td>
#       <td id="T_cb5b7_row2_col3" class="data row2 col3" >0.9965</td>
#       <td id="T_cb5b7_row2_col4" class="data row2 col4" >0.9967</td>
#       <td id="T_cb5b7_row2_col5" class="data row2 col5" >0.9966</td>
#       <td id="T_cb5b7_row2_col6" class="data row2 col6" >0.9932</td>
#       <td id="T_cb5b7_row2_col7" class="data row2 col7" >0.9932</td>
#       <td id="T_cb5b7_row2_col8" class="data row2 col8" >2.5120</td>
#     </tr>
#     <tr>
#       <th id="T_cb5b7_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_cb5b7_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_cb5b7_row3_col1" class="data row3 col1" >0.9963</td>
#       <td id="T_cb5b7_row3_col2" class="data row3 col2" >0.9997</td>
#       <td id="T_cb5b7_row3_col3" class="data row3 col3" >0.9960</td>
#       <td id="T_cb5b7_row3_col4" class="data row3 col4" >0.9966</td>
#       <td id="T_cb5b7_row3_col5" class="data row3 col5" >0.9963</td>
#       <td id="T_cb5b7_row3_col6" class="data row3 col6" >0.9926</td>
#       <td id="T_cb5b7_row3_col7" class="data row3 col7" >0.9926</td>
#       <td id="T_cb5b7_row3_col8" class="data row3 col8" >8.0250</td>
#     </tr>
#     <tr>
#       <th id="T_cb5b7_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_cb5b7_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_cb5b7_row4_col1" class="data row4 col1" >0.9962</td>
#       <td id="T_cb5b7_row4_col2" class="data row4 col2" >0.9996</td>
#       <td id="T_cb5b7_row4_col3" class="data row4 col3" >0.9961</td>
#       <td id="T_cb5b7_row4_col4" class="data row4 col4" >0.9964</td>
#       <td id="T_cb5b7_row4_col5" class="data row4 col5" >0.9962</td>
#       <td id="T_cb5b7_row4_col6" class="data row4 col6" >0.9925</td>
#       <td id="T_cb5b7_row4_col7" class="data row4 col7" >0.9925</td>
#       <td id="T_cb5b7_row4_col8" class="data row4 col8" >0.5410</td>
#     </tr>
#     <tr>
#       <th id="T_cb5b7_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_cb5b7_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_cb5b7_row5_col1" class="data row5 col1" >0.9940</td>
#       <td id="T_cb5b7_row5_col2" class="data row5 col2" >0.9940</td>
#       <td id="T_cb5b7_row5_col3" class="data row5 col3" >0.9941</td>
#       <td id="T_cb5b7_row5_col4" class="data row5 col4" >0.9938</td>
#       <td id="T_cb5b7_row5_col5" class="data row5 col5" >0.9940</td>
#       <td id="T_cb5b7_row5_col6" class="data row5 col6" >0.9879</td>
#       <td id="T_cb5b7_row5_col7" class="data row5 col7" >0.9879</td>

# %%
experiment.finalize_model(best_model)
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('placeholder', None),
#                 ('actual_estimator',
#                  LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None, random_state=123,
#                                 reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0))],
#          verbose=False)

# %%
experiment.save_model(best_model, 'lightgbm_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('placeholder', None),
#                  ('trained_model',
#                   LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                  colsample_bytree=1.0, importance_type='split',
#                                  learning_rate=0.1, max_depth=-1,
#                                  min_child_samples=20, min_child_weight=0.001,
#                                  min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                  num_leaves=31, objective=None, random_state=123,
#                                  reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                                  subsample_for_bin=200000, subsample_freq=0))],
#           verbose=False),
#  'lightgbm_model.pkl')
